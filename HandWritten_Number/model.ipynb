# %%
# !pip install tensorflow==2.2.1
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.2.1 (from versions: 2.5.0, 2.5.1, 2.5.2, 2.5.3, 2.6.0rc0, 2.6.0rc1, 2.6.0rc2, 2.6.0, 2.6.1, 2.6.2, 2.6.3, 2.6.4, 2.6.5, 2.7.0rc0, 2.7.0rc1, 2.7.0, 2.7.1, 2.7.2, 2.7.3, 2.7.4, 2.8.0rc0, 2.8.0rc1, 2.8.0, 2.8.1, 2.8.2, 2.8.3, 2.8.4, 2.9.0rc0, 2.9.0rc1, 2.9.0rc2, 2.9.0, 2.9.1, 2.9.2, 2.9.3, 2.10.0rc0, 2.10.0rc1, 2.10.0rc2, 2.10.0rc3, 2.10.0, 2.10.1, 2.11.0rc0, 2.11.0rc1, 2.11.0rc2, 2.11.0, 2.11.1, 2.12.0rc0, 2.12.0rc1, 2.12.0, 2.12.1, 2.13.0rc0, 2.13.0rc1, 2.13.0rc2, 2.13.0, 2.13.1, 2.14.0rc0, 2.14.0rc1, 2.14.0, 2.14.1, 2.15.0rc0, 2.15.0rc1, 2.15.0, 2.15.1, 2.16.0rc0, 2.16.1)
# ERROR: No matching distribution found for tensorflow==2.2.1

# %%
import tensorflow as tf
mnist = tf.keras.datasets.mnist
# Out:
# C:\Users\shahabuddin akhon hr\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\tensorflow\python\util\lazy_loader.py:147, in KerasLazyLoader._initialize(self)
#     146 try:
# --> 147   import keras  # pylint: disable=g-import-not-at-top
#     149   if keras.__version__.startswith("3."):
#     150     # This is the Keras 3.x case.
#
# File ~\anaconda3\lib\site-packages\keras\__init__.py:10, in <module>
#       9 # Import everything from /api/ into keras.
# ---> 10 from keras.api import *  # noqa: F403
#      11 from keras.api import __version__  # Import * ignores names start with "_".
#
# ...
